# %%
# importing libraries
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_excel (r'./GTT_2 (2).xlsx', index_col=0)
df
# Out:
#        1_Fasting  2_Fasting  3_Fasting  4_Fasting  5_Fasting  6_Fasting  \
# Group
# 0min          75         77         85         86        103         81
# 30min        140        159        158        190        141        131
# 60min        154        135        174        254        171        152
# 90min        151        141        133        210        170        185
#
#        7_Fasting  Fasting_avg  Fasting_sem
# Group
# 0min          83        80.75     2.101587
# 30min        161       161.75     7.845988
# 60min        180       179.25    19.773419
# 90min        191       158.75    13.210295

# %%
df = df.dropna()
df
# Out:
#        1_Fasting  2_Fasting  3_Fasting  4_Fasting  5_Fasting  6_Fasting  \
# Group
# 0min          75         77         85         86        103         81
# 30min        140        159        158        190        141        131
# 60min        154        135        174        254        171        152
# 90min        151        141        133        210        170        185
#
#        7_Fasting  Fasting_avg  Fasting_sem
# Group
# 0min          83        80.75     2.101587
# 30min        161       161.75     7.845988
# 60min        180       179.25    19.773419
# 90min        191       158.75    13.210295

# %%
fig, ax = plt.subplots()
df.plot.line(ax = ax, y = 'Fasting_avg',color = 'r', marker = 'o', yerr = 'Fasting_sem', capsize=5)
ax.set_xlabel("Time (min)")
ax.set_ylabel("Blood Glucose (mg/dL)")
# Out:
# Text(0, 0.5, 'Blood Glucose (mg/dL)')

# %% [markdown]
# ![image.png](data:image/png;base64,...)
